# %% [markdown]
# <a href="https://colab.research.google.com/github/Mohneesh09/ML-Contest-on-Liver-Disease-Prediction-/blob/main/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install flask
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: flask in /usr/local/lib/python3.10/dist-packages (2.2.4)
# Requirement already satisfied: Werkzeug>=2.2.2 in /usr/local/lib/python3.10/dist-packages (from flask) (2.3.0)
# Requirement already satisfied: Jinja2>=3.0 in /usr/local/lib/python3.10/dist-packages (from flask) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.0 in /usr/local/lib/python3.10/dist-packages (from flask) (2.1.2)
# Requirement already satisfied: click>=8.0 in /usr/local/lib/python3.10/dist-packages (from flask) (8.1.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.0->flask) (2.1.2)

# %%
pip install tokenizers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: tokenizers in /usr/local/lib/python3.10/dist-packages (0.13.3)

# %%
pip install transformers

# %%
pip install SentencePiece
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: SentencePiece in /usr/local/lib/python3.10/dist-packages (0.1.99)

# %%
pip install langchain

# %%
pip install openai

# %%
import pipreqs

# %%
# !pip install pipdeptree
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pipdeptree
#   Downloading pipdeptree-2.8.0-py3-none-any.whl (18 kB)
# Installing collected packages: pipdeptree
# Successfully installed pipdeptree-2.8.0

# %%
# !pipdeptree --freeze > requirements.txt

# %%
from google.colab import files
files.download('requirements.txt')

# %%
from transformers import AutoTokenizer, AutoModelWithLMHead

tokenizer = AutoTokenizer.from_pretrained("mrm8488/t5-base-finetuned-emotion")
model = AutoModelWithLMHead.from_pretrained("mrm8488/t5-base-finetuned-emotion")
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/25.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.21k [00:00<?, ?B/s]
# Downloading (…)ve/main/spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/1.79k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1362: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# Downloading pytorch_model.bin:   0%|          | 0.00/892M [00:00<?, ?B/s]

# %%
import os 
os.makedirs("path/to/model1") 
os.makedirs("path/to/tokenizer")

# %%
model.save_pretrained("path/to/model1")

# %%
from transformers import T5ForConditionalGeneration, T5Tokenizer

model_path = "path/to/model1"

# Load the saved model
model1 = T5ForConditionalGeneration.from_pretrained(model_path)

# %%
tokenizer.save_pretrained("path/to/tokenizer")
tokenizer = T5Tokenizer.from_pretrained("path/to/tokenizer")

# %%
def emotion(text):
  input_ids = tokenizer.encode(text + '</s>', return_tensors='pt')

  output = model1.generate(input_ids=input_ids,
               max_length=2)
  
  dec = [tokenizer.decode(ids) for ids in output]
  label = dec[0]
  return label

# %%
mood='fear'

# %%
# Define the prompts and questions
import os
import openai
from langchain import PromptTemplate, LLMChain
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI, OpenAIChat

OPEN_AI_SECRET = "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"
os.environ['OPENAI_API_KEY'] = OPEN_AI_SECRET

book = book1

texts= f"You are a motivator.You have been given with 6 classes sadness, joy, anger, fear, surprise, love. If you are given sadness, anger or fear try to comfort and motivate user with quote  from {book} else encourage user to be same."

prefix_messages = [{"role": "system", "content": texts}]

llm = OpenAIChat(model_name='gpt-3.5-turbo', temperature=1, prefix_messages=prefix_messages,max_tokens = 256)

template1 = """Take the following emotion {user_input} category as input and give a proper quote  from in english with citation which comfort the user. I just want the quote don't reveal the emotion of user in output and don't let them know the emotion"""

user_input='sadness'
prompt1 = PromptTemplate(template=template1,  input_variables=["user_input"])

llm_chain = LLMChain(prompt=prompt1, llm=llm)

prediction=llm_chain.run(user_input)
print(prediction)
# Out:
# "Health is the greatest gift, contentment the greatest wealth, faithfulness the best relationship." - Buddha, Dhammapada
#
# This quote reminds us to focus on what truly matters in life, which is our health, contentment, and being faithful to ourselves. It's easy to get caught up in our emotions and forget about what makes us truly happy. By remembering these simple truths, we can find comfort and motivate ourselves to stay on the right path in life.

# %%
from flask import Flask, render_template, request
from transformers import T5ForConditionalGeneration, T5Tokenizer
import numpy as np
import pandas as pd
import random
import os
import openai
from langchain import PromptTemplate, LLMChain
from langchain.prompts import PromptTemplate
from langchain.llms import OpenAI, OpenAIChat

OPEN_AI_SECRET = "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"
os.environ['OPENAI_API_KEY'] = OPEN_AI_SECRET

app = Flask(__name__, template_folder='templateFiles',
            static_folder='staticFiles')

def emotion(text):
  input_ids = tokenizer.encode(text + '</s>', return_tensors='pt')

  output = model1.generate(input_ids=input_ids,
               max_length=2)
  
  dec = [tokenizer.decode(ids) for ids in output]
  label = dec[0]
  return label

def LLM_quote(mood,book1):
  list1 = ['Bhagavad Gita', 'Bible', 'Quran','Dhammapada','Guru Granth Sahib'] 
  book = random.choice(list1)
  texts= f"You are a motivator.You have been given with 6 classes sadness, joy, anger, fear, surprise, love. If you are given sadness, anger or fear try to comfort and motivate user with quote  from {book} else encourage user to be same."
  prefix_messages = [{"role": "system", "content": texts}]

  llm = OpenAIChat(model_name='gpt-3.5-turbo', temperature=0.7, prefix_messages=prefix_messages,max_tokens = 100)

  template1 = """Take the following emotion {user_input} category as input and give a proper quote  from in english with citation which comfort the user. I just want the quote don't reveal the emotion of user in output and don't let them know the emotion"""
  user_input=mood
  prompt1 = PromptTemplate(template=template1,  input_variables=["user_input"])

  llm_chain = LLMChain(prompt=prompt1, llm=llm)

  quote=llm_chain.run(user_input)
  return quote    

@app.route('/')
def start():
    return render_template('index.html')



@app.route('/predict', methods=['GET', 'POST'])
def predict_riskTolerance():
    tokenizer_path= "/content/path/to/tokenizer"
    model_path = "/content/path/to/model1"
    model1 = T5ForConditionalGeneration.from_pretrained(model_path)
    tokenizer = T5Tokenizer.from_pretrained(tokenizer_path)
  
    text = request.form['answer1']    #text store the answer received from user.
    mood =emotion(text)
    mood=mood[5: ] 

    quote= LLM_quote(mood)        #Quote to be shown to the user.          
    # Nwcat = Nwcat*1000000
    return render_template('dashboard.html', riskTolerance=mood, options=options)
    # return options


if __name__ == '__main__':
    app.run(debug=True, host='0.0.0.0')
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on all addresses (0.0.0.0)
#  * Running on http://127.0.0.1:5000
#  * Running on http://172.28.0.12:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug: * Restarting with stat
